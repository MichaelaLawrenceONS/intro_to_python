# %% [markdown]
# # Introduction to Python Week One

# %% [markdown]
# Welcome to the Data Products, Services, and Governance division introduction to Python learning materials. These materials have been adapted from a classroom-based training series. Adapted so that they can be followed without additional teacher instruction as much as possible.

# %% [markdown]
# There are many reasons for taking part in introductory Python training:
# - It is directly needed for your role in the ONS e.g. you are a new DPSG apprentice and need to learn Python to get started with data engineering.
# - It maybe/ will be a part of your role in the future e.g. you currently use Excel/ SAS and there are discussions in your group about moving away from these tools towards an open-source solution.
# - Your role requires no Python, but you suspect Python could be used to improve parts of your daily work e.g. You are looking to use Python to automate soma part of your work process.
# - Just because/ you’re just looking.

# %% [markdown]
# There are a plethora of fantastic introductory Python training and data focussed training in the public domain. I wont list them all here, but some good examples of a general Python introduction are [freeCodeCamp](https://www.freecodecamp.org/) and [CS50P](https://www.youtube.com/playlist?list=PLhQjrBD2T3817j24-GogXmWqO5Q5vYy0V). These resources are fantastic and will provide a solid foundation in Python. Additionally, throughout this training series we reference several specific learning resources – specific either to data manipulation, a civil service context or an ONS context.
#
# The purpose of this training series is to create a short, public, beginner friendly collection of teaching resources that are relevant specifically to ONS colleagues who are looking to use Python to work with data but that also caters to all the motivated learners mentioned above.

# %%
import pandas as pd
# Out:
# C:\Users\lawrem1\Anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %%
df = pd.read_csv('2011.csv', header = 1)

# %%
df.head()
# Out:
#    Person ID     Region Residence Type  Family Composition  Population Base  \
# 0    7394816  E12000001              H                   2                1
# 1    7394745  E12000001              H                   5                1
# 2    7395066  E12000001              H                   3                1
# 3    7395329  E12000001              H                   3                1
# 4    7394712  E12000001              H                   3                1
#
#    Sex  Age  Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 0    2    6               2        2                 1       2             1
# 1    1    4               1        2                 1       1             1
# 2    2    4               1        2                 1       1             1
# 3    2    2               1        2                 1       2             1
# 4    1    5               4        2                 1       1             1
#
# ...

# %%
df.tail()
# Out:
#         Person ID     Region Residence Type  Family Composition  \
# 569736    7946020  W92000004              H                   1
# 569737    7944310  W92000004              H                   3
# 569738    7945374  W92000004              H                   3
# 569739    7944768  W92000004              H                   1
# 569740    7944959  W92000004              H                   2
#
#         Population Base  Sex  Age  Marital Status  Student  Country of Birth  \
# 569736                1    1    5               1        2                 1
# 569737                1    1    3               1        2                 1
# 569738                1    1    1               1        1                 1
# 569739                1    2    8               5        2                 1
# 569740                1    2    2               2        2                 1
#
#         Health  Ethnic Group  Religion  Economic Activity  Occupation  \
# ...

# %%
df.shape
# Out:
# (569741, 18)

# %%
df.describe()
# Out:
#           Person ID  Family Composition  Population Base            Sex  \
# count  5.697410e+05       569741.000000    569741.000000  569741.000000
# mean   7.679353e+06            2.011870         1.018731       1.507550
# std    1.644702e+05            2.358788         0.159058       0.499943
# min    7.394483e+06           -9.000000         1.000000       1.000000
# 25%    7.536918e+06            2.000000         1.000000       1.000000
# 50%    7.679353e+06            2.000000         1.000000       2.000000
# 75%    7.821788e+06            3.000000         1.000000       2.000000
# max    7.964223e+06            6.000000         3.000000       2.000000
#
#                  Age  Marital Status        Student  Country of Birth  \
# count  569741.000000   569741.000000  569741.000000     569741.000000
# mean        3.978680        1.856201       1.777904          1.016239
# std         2.219494        1.125020       0.415655          1.153095
# ...
